# %% [markdown]
# # Using Tools with our Autogen Agent

# %% [markdown]
# Its like giving our assistant a toolbox to solve the problems.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %% [markdown]
# # Tools
#
# 'What's the weather in new York'
#
# Special Functions that let the agents do things like fetch data, calculate numbers or even call external services.
#
# WIthout tools, agent can only chat. With tools, they can act.

# %%
def get_weather(city:str) -> str:
    """
    Fetches the weather for a given city.
    This is a placeholder function and should be replaced with actual weather fetching logic.
    For example, you could use a weather API to get real-time data.
    :param city: Name of the city to fetch weather for.
    :return: Weather information as a string.
    """
    # Placeholder function to simulate weather fetching
    return f"The weather in {city} is sunny with a high of 35°C."

def celsius_to_fahrenheit(celsius:float) -> float:
    '''
    Convert Celsius temp to Fahrenheit temp.

    input:
    celsius : float

    output
    temperature in fahrenhiet : float
    '''
    return (celsius * 9/5) + 32

# %%
assistant = AssistantAgent(
    name = 'weather_assistant',
    model_client=model_client,
    system_message='You are a weather assistant, Use the get_weather tool when asked about the weather in a city, and use the celsius_to_fahrenheit tool to convert temperatures from Celsius to Fahrenheit.',
    tools= [get_weather, celsius_to_fahrenheit],
    reflect_on_tool_use=True
)

# %%
assistant_2 = AssistantAgent(
    name = 'weather_assistant',
    model_client=model_client,
    tools= [get_weather, celsius_to_fahrenheit],
    reflect_on_tool_use=True
)

# %%
async def test_weather_tool():
    result = await assistant.run(task = 'What is the weather in New York?')
    print(result.messages[-1].content)

# %%
await test_weather_tool()
# Out:
# The current weather in New York is sunny, with a high temperature of 35°C.

# %%
async def test_temp_conv_tool():
    result = await assistant.run(task = 'What is the 35 degree celcius in farhenhiet?')
    print(result.messages[-1].content)

# %%
await test_temp_conv_tool()
# Out:
# 35 degrees Celsius is equivalent to 95 degrees Fahrenheit.

# %%
async def test_temp_conv_tool():
    result = await assistant_2.run(task = 'What is the 35 degree celcius in farhenhiet?')
    print(result.messages[-1].content)
    print(result.messages)

await test_temp_conv_tool()
# Out:
# 35 degrees Celsius is equivalent to 95 degrees Fahrenheit. TERMINATE
# [TextMessage(id='c5b9b3e6-d2bd-43a4-8bb0-6be1c543ca31', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 25, 5, 46, 40, 544785, tzinfo=datetime.timezone.utc), content='What is the 35 degree celcius in farhenhiet?', type='TextMessage'), ToolCallRequestEvent(id='c378858a-9307-4d94-8582-14649c32c6f1', source='weather_assistant', models_usage=RequestUsage(prompt_tokens=262, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 10, 25, 5, 46, 41, 507526, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_r8vqgsBL7REiQA8P7sFYWwfa', arguments='{"celsius":35}', name='celsius_to_fahrenheit')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='3ebf6e9f-c396-4504-ad71-cf6737b4b8dd', source='weather_assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 25, 5, 46, 41, 509866, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='95.0', name='celsius_to_fahrenheit', call_id='call_r8vqgsBL7REiQA8P7sFYWwfa', is_error=False)], type='ToolCallExecutionEvent'), TextMessage(id='cb2d12c8-cdba-45ca-87f2-9fdeb74006ec', source='weather_assistant', models_usage=RequestUsage(prompt_tokens=150, completion_tokens=13), metadata={}, created_at=datetime.datetime(2025, 10, 25, 5, 46, 42, 405042, tzinfo=datetime.timezone.utc), content='35 degrees Celsius is equivalent to 95 degrees Fahrenheit. TERMINATE', type='TextMessage')]
