# %% [markdown]
# # Observe a running team in Autogen

# %%
import asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %%
from autogen_agentchat.agents import AssistantAgent
plot_agent = AssistantAgent(
    name = 'plot_writer',
    model_client=model_client,
    system_message="You create engaging plots for stories. Focus on the Knight's journey.compelte it in 10 words"
)

character_agent = AssistantAgent(
    name = 'character_writer',
    model_client=model_client,
    system_message="You develop characters. Describe the knight and the dragon in detail, including their motivations and backgrounds.compelte it in 10 words"
)

ending_agent = AssistantAgent(
    name = 'ending_writer',
    model_client=model_client,
    system_message="You write engaging endings. conclude the story with a twist. compelte it in 10 words"
)

# %%
from autogen_agentchat.teams import RoundRobinGroupChat

team = RoundRobinGroupChat(
    participants = [plot_agent, character_agent, ending_agent],
    max_turns=3
)

# %%
await team.run(task = "Write a poem on the Sprint Season")
# Out:
# TaskResult(messages=[TextMessage(id='0815db44-6520-462d-8e6a-c07e60c72df0', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 6, 17, 799635, tzinfo=datetime.timezone.utc), content='Write a poem on the Sprint Season', type='TextMessage'), TextMessage(id='a91e7bb5-a50c-4607-9c51-b0894d02a4fb', source='plot_writer', models_usage=RequestUsage(prompt_tokens=39, completion_tokens=80), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 6, 22, 810036, tzinfo=datetime.timezone.utc), content="Buds bloom, earth wakes,  \nColorful fields, life remakes.  \nGentle rain, softly falls,  \nNature's vibrant, joyous calls.  \nBlossom scents fill the air,  \nSpring whispers everywhere.  \nWarmth returns, so does light,  \nDay grows long, chases night.  \nHope renewed, spirits lift,  \nSpring's embrace, nature's gift.", type='TextMessage'), TextMessage(id='24aafb15-77bd-4ade-a2d7-fcd499a4a678', source='character_writer', models_usage=RequestUsage(prompt_tokens=131, completion_tokens=29), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 6, 24, 253013, tzinfo=datetime.timezone.utc), content='Knight: Brave heart, noble, seeking redemption through heroic deeds.  \nDragon: Ancient, wise, guards treasure, desires peace over conflict.  ', type='TextMessage'), TextMessage(id='ca6deba7-2de9-46b9-83b8-5cf0587c0749', source='ending_writer', models_usage=RequestUsage(prompt_tokens=161, completion_tokens=239), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 6, 27, 159569, tzinfo=datetime.timezone.utc), content='As the knight faced the dragon, tension filled the air. Fearful yet determined, he raised his sword, ready to strike. But the dragon, instead of retaliating, spoke with a soft, rumbling voice, "Seek not to harm, brave knight. Instead, a riddle for peace."\n\nIntrigued, the knight hesitated and nodded. The dragon continued, "Answer true, and my treasure is yours without battle. What has keys but opens no locks, with strings yet creates no sound?"\n\nThe knight pondered deeply, eyes glancing at the musical instruments in the cave. Suddenly, realization struck. "A keyboard," he declared.\n\nWith a nod, the dragon smiled, as if a heavy weight had lifted off its ancient shoulders, "Indeed, you\'ve brought harmony without conflict."\n\nThe knight, relieved, turned away from the treasure, having gained a wisdom far more valuable. \n\nFor years, tales spread of a knight\'s courage, not from battle, but from understanding. And somewhere, the dragon watched over its land, treasure intact, grateful for peace.\n\nNothing was as it seemed in this ancient lair - \nKnight became storyteller, and dragon the world\'s fair.', type='TextMessage')], stop_reason='Maximum number of turns 3 reached.')

# %%
from autogen_agentchat.base import TaskResult

async for message in team.run_stream(task = 'Write a poem on the Spring Season'):
    print((message))
# Out:
# id='1981089c-b76d-43aa-a798-e04bcf9306e1' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 51, 42, 532378, tzinfo=datetime.timezone.utc) content='Write a poem on the Spring Season' type='TextMessage'
# id='20b0577f-6c5d-4eea-bffd-2c28c5172040' source='plot_writer' models_usage=RequestUsage(prompt_tokens=148, completion_tokens=36) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 51, 43, 572422, tzinfo=datetime.timezone.utc) content="Gentle breezes, blossoms bright,  \nAwakening earth from winter's night.  \nJoyful songs in morning light,  \nSpring's embrace, a pure delight.  " type='TextMessage'
# id='8e92322a-6441-4bf4-a11e-d0286c513f12' source='character_writer' models_usage=RequestUsage(prompt_tokens=196, completion_tokens=37) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 51, 44, 563130, tzinfo=datetime.timezone.utc) content="Petals glide on gentle breeze,  \nAwakening earth, birds in trees.  \nSunlit days and nights aglow,  \nSpring's soft whispers, life to sow.  " type='TextMessage'
# id='cccc396a-d24c-463c-b470-aa5b677743f1' source='ending_writer' models_usage=RequestUsage(prompt_tokens=234, completion_tokens=52) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 51, 46, 322605, tzinfo=datetime.timezone.utc) content="Colors burst as life renews,  \nHope reborn in morning hues.  \nNature's dance in vibrant spree,  \nSpring's embrace, wild and free.  \n\nBut as blossoms fade to dusk's glow,  \nSummer's heat conceals winter's snow." type='TextMessage'
# messages=[TextMessage(id='1981089c-b76d-43aa-a798-e04bcf9306e1', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 51, 42, 532378, tzinfo=datetime.timezone.utc), content='Write a poem on the Spring Season', type='TextMessage'), TextMessage(id='20b0577f-6c5d-4eea-bffd-2c28c5172040', source='plot_writer', models_usage=RequestUsage(prompt_tokens=148, completion_tokens=36), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 51, 43, 572422, tzinfo=datetime.timezone.utc), content="Gentle breezes, blossoms bright,  \nAwakening earth from winter's night.  \nJoyful songs in morning light,  \nSpring's embrace, a pure delight.  ", type='TextMessage'), TextMessage(id='8e92322a-6441-4bf4-a11e-d0286c513f12', source='character_writer', models_usage=RequestUsage(prompt_tokens=196, completion_tokens=37), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 51, 44, 563130, tzinfo=datetime.timezone.utc), content="Petals glide on gentle breeze,  \nAwakening earth, birds in trees.  \nSunlit days and nights aglow,  \nSpring's soft whispers, life to sow.  ", type='TextMessage'), TextMessage(id='cccc396a-d24c-463c-b470-aa5b677743f1', source='ending_writer', models_usage=RequestUsage(prompt_tokens=234, completion_tokens=52), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 51, 46, 322605, tzinfo=datetime.timezone.utc), content="Colors burst as life renews,  \nHope reborn in morning hues.  \nNature's dance in vibrant spree,  \nSpring's embrace, wild and free.  \n\nBut as blossoms fade to dusk's glow,  \nSummer's heat conceals winter's snow.", type='TextMessage')] stop_reason='Maximum number of turns 3 reached.'

# %%
from autogen_agentchat.base import TaskResult

async for message in team.run_stream(task = 'Write a story on the Spring Season'):
    print((message))
# Out:
# id='df8e5c83-6e0a-4ac5-83a9-29bf32fb8de5' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 52, 53, 266735, tzinfo=datetime.timezone.utc) content='Write a story on the Spring Season' type='TextMessage'
# id='412fe037-1460-4c5d-a4c9-fc8c2ddc5a97' source='plot_writer' models_usage=RequestUsage(prompt_tokens=303, completion_tokens=330) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 52, 57, 457235, tzinfo=datetime.timezone.utc) content="In the heart of a tranquil village, nestled between emerald hills, spring arrived like an artist with a vibrant palette. Flowers bloomed into jubilant colors, painting the fields in hues of purple and yellow. The air was sweet with the scent of blossoms, mingling with the earthy aroma of freshly-tilled soil. Children laughed as they chased butterflies along the cobblestone paths.\n\nEvery year, the villagers honored the season with a festival, celebrating the earth's awakening. In preparation, families gathered to weave garlands and prepare feasts from the first harvests. The centerpiece was the grand maypole, adorned with ribbons of every shade, beneath which they danced to the melodies played by local musicians.\n\nAmidst the preparations, a humble gardener named Elara worked tirelessly in her modest plot. Known for her green thumb, Elara grew the most colorful flowers and the juiciest fruits. This year, she had a secret project—cultivating a rare blue rose, believed to bring good fortune.\n\nAs the festival day dawned, Elara unveiled her creation, a glowing blue amidst a sea of color. The villagers were mesmerized, their spirits lifted by the sight. Legend spoke that the blue rose could grant a single wish, and with the thrill of possibility in their hearts, they gathered to make a collective wish for a bountiful year.\n\nAs the sun set, casting a golden glow over the festivities, Elara found herself smiling. Her flower was a small symbol of the community's spirit, united in the celebration of life's endless cycle. With that, spring's enchanting story continued, as vibrant and promising as ever." type='TextMessage'
# id='018579bc-7c37-4e60-acf1-1b830f5a5fed' source='character_writer' models_usage=RequestUsage(prompt_tokens=645, completion_tokens=222) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 53, 0, 753892, tzinfo=datetime.timezone.utc) content="As the moon rose over the festival, its silver light dancing on the hilltops, the elders shared tales of springs past around the fire, their voices a comforting melody in the cool night air. The laughter of the young mixed with the crackling flames, a testament to the enduring spirit of their village.\n\nElara, basking in the joy she had helped nurture, sat quietly listening. She knew that in every petal, in every gust of wind, there was a whisper of history—a reminder that each season was its own story, woven with hope, resilience, and the promise of renewal. Her blue rose, though rare and magical, was but a single chapter in spring's eternal tale.\n\nAs dawn broke, the festival drew to a close, yet the spirit of spring lingered in the hearts of all. Elara returned to her garden, her soul at peace, knowing she had played her part in the timeless dance of seasons. With a heart full of gratitude, she tended her blooms, for in tending the earth, she tended her dreams, nurturing life's continuous rebirth with each passing spring." type='TextMessage'
# id='815e65d0-8f13-46fe-aa52-fed372bb9e6d' source='ending_writer' models_usage=RequestUsage(prompt_tokens=868, completion_tokens=33) metadata={} created_at=datetime.datetime(2026, 2, 28, 9, 53, 1, 889420, tzinfo=datetime.timezone.utc) content='But as Elara gazed at her blue rose, it whispered, "Your wish?" Surprised, she wished, and the village awoke in summer.' type='TextMessage'
# messages=[TextMessage(id='df8e5c83-6e0a-4ac5-83a9-29bf32fb8de5', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 52, 53, 266735, tzinfo=datetime.timezone.utc), content='Write a story on the Spring Season', type='TextMessage'), TextMessage(id='412fe037-1460-4c5d-a4c9-fc8c2ddc5a97', source='plot_writer', models_usage=RequestUsage(prompt_tokens=303, completion_tokens=330), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 52, 57, 457235, tzinfo=datetime.timezone.utc), content="In the heart of a tranquil village, nestled between emerald hills, spring arrived like an artist with a vibrant palette. Flowers bloomed into jubilant colors, painting the fields in hues of purple and yellow. The air was sweet with the scent of blossoms, mingling with the earthy aroma of freshly-tilled soil. Children laughed as they chased butterflies along the cobblestone paths.\n\nEvery year, the villagers honored the season with a festival, celebrating the earth's awakening. In preparation, families gathered to weave garlands and prepare feasts from the first harvests. The centerpiece was the grand maypole, adorned with ribbons of every shade, beneath which they danced to the melodies played by local musicians.\n\nAmidst the preparations, a humble gardener named Elara worked tirelessly in her modest plot. Known for her green thumb, Elara grew the most colorful flowers and the juiciest fruits. This year, she had a secret project—cultivating a rare blue rose, believed to bring good fortune.\n\nAs the festival day dawned, Elara unveiled her creation, a glowing blue amidst a sea of color. The villagers were mesmerized, their spirits lifted by the sight. Legend spoke that the blue rose could grant a single wish, and with the thrill of possibility in their hearts, they gathered to make a collective wish for a bountiful year.\n\nAs the sun set, casting a golden glow over the festivities, Elara found herself smiling. Her flower was a small symbol of the community's spirit, united in the celebration of life's endless cycle. With that, spring's enchanting story continued, as vibrant and promising as ever.", type='TextMessage'), TextMessage(id='018579bc-7c37-4e60-acf1-1b830f5a5fed', source='character_writer', models_usage=RequestUsage(prompt_tokens=645, completion_tokens=222), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 53, 0, 753892, tzinfo=datetime.timezone.utc), content="As the moon rose over the festival, its silver light dancing on the hilltops, the elders shared tales of springs past around the fire, their voices a comforting melody in the cool night air. The laughter of the young mixed with the crackling flames, a testament to the enduring spirit of their village.\n\nElara, basking in the joy she had helped nurture, sat quietly listening. She knew that in every petal, in every gust of wind, there was a whisper of history—a reminder that each season was its own story, woven with hope, resilience, and the promise of renewal. Her blue rose, though rare and magical, was but a single chapter in spring's eternal tale.\n\nAs dawn broke, the festival drew to a close, yet the spirit of spring lingered in the hearts of all. Elara returned to her garden, her soul at peace, knowing she had played her part in the timeless dance of seasons. With a heart full of gratitude, she tended her blooms, for in tending the earth, she tended her dreams, nurturing life's continuous rebirth with each passing spring.", type='TextMessage'), TextMessage(id='815e65d0-8f13-46fe-aa52-fed372bb9e6d', source='ending_writer', models_usage=RequestUsage(prompt_tokens=868, completion_tokens=33), metadata={}, created_at=datetime.datetime(2026, 2, 28, 9, 53, 1, 889420, tzinfo=datetime.timezone.utc), content='But as Elara gazed at her blue rose, it whispered, "Your wish?" Surprised, she wished, and the village awoke in summer.', type='TextMessage')] stop_reason='Maximum number of turns 3 reached.'

# %%
print(message)
# Out:
# messages=[TextMessage(id='9f5e7cd1-c6ea-4170-9492-04b5ed04cbf5', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 19, 461482, tzinfo=datetime.timezone.utc), content='Write a poem on the Spring Season', type='TextMessage'), TextMessage(id='303f9fba-9858-4f28-af5c-75b01733157e', source='plot_writer', models_usage=RequestUsage(prompt_tokens=754, completion_tokens=18), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 20, 293952, tzinfo=datetime.timezone.utc), content="Blossoms emerge, warmth spreads, skies clear; nature's canvas reborn softly.", type='TextMessage'), TextMessage(id='8b516ecd-2aca-42f7-8116-73a1218f91d0', source='character_writer', models_usage=RequestUsage(prompt_tokens=741, completion_tokens=20), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 21, 260505, tzinfo=datetime.timezone.utc), content="Gentle rain falls, seeds sprout, birds serenade; Spring's gentle touch awakens.", type='TextMessage'), TextMessage(id='6bcd0584-e1fc-477e-a409-61e991d60ec7', source='ending_writer', models_usage=RequestUsage(prompt_tokens=785, completion_tokens=18), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 22, 312298, tzinfo=datetime.timezone.utc), content="Earth smiles, vibrant blooms; shadows fade, winter whispers—Spring's eternal secrets unveiled.", type='TextMessage')] stop_reason='Maximum number of turns 3 reached.'

# %%
from autogen_agentchat.base import TaskResult

async for message in team.run_stream(task = 'Write a poem on the Spring Season'):
    if isinstance(message,TaskResult):
        print(f"Stop Reason: {message.stop_reason}")
    else:
        print((message))
# Out:
# id='08477bec-b2b2-49b4-b7eb-924602e95e2b' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 28, 4, 16, 22, 439017, tzinfo=datetime.timezone.utc) content='Write a poem on the Spring Season' type='TextMessage'
# id='16578bb0-7d1d-430e-ba7a-357de9ec5fdc' source='plot_writer' models_usage=RequestUsage(prompt_tokens=840, completion_tokens=19) metadata={} created_at=datetime.datetime(2026, 2, 28, 4, 16, 23, 80526, tzinfo=datetime.timezone.utc) content='Petals unfurl, life glistens, soft winds sing; new dreams bloom brightly.' type='TextMessage'
# id='86024546-e6ef-4df9-a230-cbfd1bf8228e' source='character_writer' models_usage=RequestUsage(prompt_tokens=828, completion_tokens=19) metadata={} created_at=datetime.datetime(2026, 2, 28, 4, 16, 23, 925451, tzinfo=datetime.timezone.utc) content='Hues collide, earth hums, rivers dance; Spring breathes life anew tenderly.' type='TextMessage'
# id='32cadcc2-bc8e-4bc3-b96f-3eb4231c3b73' source='ending_writer' models_usage=RequestUsage(prompt_tokens=871, completion_tokens=16) metadata={} created_at=datetime.datetime(2026, 2, 28, 4, 16, 24, 743147, tzinfo=datetime.timezone.utc) content="Sunrise paints fields, hope rises; Spring's secret kiss births eternal love." type='TextMessage'
# Stop Reason: Maximum number of turns 3 reached.

# %%
from autogen_agentchat.ui import Console

await Console(team.run_stream(task = 'Write a poem on the Spring Season'))
# Out:
# ---------- TextMessage (user) ----------
# Write a poem on the Spring Season
# ---------- TextMessage (plot_writer) ----------
# Blossoms burst, nature's stage,
# Sunlight pours on every page.
# Breezes warm, sweet scents play,
# New life whispers, come what may.
# Fields of green, lively grace,
# Colorful blooms in every space.
# Birds return, songs of cheer,
# Springtime magic drawing near.
# Hope reborn, spirits rise,
# Spring unfolds beneath blue skies.
# ---------- TextMessage (character_writer) ----------
# Winter fades, spring awakes,
# Nature blooms, life partakes.
# Joyful hues, gentle rains,
# Life anew, breaking chains.
# Chirping birds, skies clear,
# Spring's renewal, warmth near.
# Vibrant fields, blossoms sprout,
# Life's renewal, all about.
# Hope rekindled, spirits sing,
# In the embrace of nurturing spring.
# ---------- TextMessage (ending_writer) ----------
# Petals whisper secrets of time, warm breezes tell tales
# Sunny smiles brush mornings, life’s joys set sail.
#
# Blooms dance in colorful hues, painting the day bright,
# Rains gently cleanse, as nature ignites.
#
# Chirping returns, echoes of hope in the air,
# Spring's renewal whispers life’s promise everywhere.
#
# Amidst vibrant shades, fields blossom and sprout,
# New life awakens, casting winter's doubts.
#
# Yet in the sun's glow, a shadow's gentle tease:
# Behind spring's rebirth, lingers an autumn breeze.
# TaskResult(messages=[TextMessage(id='2ad4443b-c022-43ad-b176-f112e2cd21c6', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 9, 7, 86514, tzinfo=datetime.timezone.utc), content='Write a poem on the Spring Season', type='TextMessage'), TextMessage(id='544a594f-5e7f-40ac-94f8-0bca831f03f2', source='plot_writer', models_usage=RequestUsage(prompt_tokens=417, completion_tokens=83), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 9, 9, 641889, tzinfo=datetime.timezone.utc), content="Blossoms burst, nature's stage,  \nSunlight pours on every page.  \nBreezes warm, sweet scents play,  \nNew life whispers, come what may.  \nFields of green, lively grace,  \nColorful blooms in every space.  \nBirds return, songs of cheer,  \nSpringtime magic drawing near.  \nHope reborn, spirits rise,  \nSpring unfolds beneath blue skies.", type='TextMessage'), TextMessage(id='991ac738-1e1b-4625-ab9d-bdaaa73e4f72', source='character_writer', models_usage=RequestUsage(prompt_tokens=512, completion_tokens=82), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 9, 11, 223506, tzinfo=datetime.timezone.utc), content="Winter fades, spring awakes,  \nNature blooms, life partakes.  \nJoyful hues, gentle rains,  \nLife anew, breaking chains.  \nChirping birds, skies clear,  \nSpring's renewal, warmth near.  \nVibrant fields, blossoms sprout,  \nLife's renewal, all about.  \nHope rekindled, spirits sing,  \nIn the embrace of nurturing spring.", type='TextMessage'), TextMessage(id='c77492c3-5337-482b-bad6-008400a183af', source='ending_writer', models_usage=RequestUsage(prompt_tokens=595, completion_tokens=122), metadata={}, created_at=datetime.datetime(2026, 6, 27, 3, 9, 13, 232551, tzinfo=datetime.timezone.utc), content="Petals whisper secrets of time, warm breezes tell tales  \nSunny smiles brush mornings, life’s joys set sail.  \n\nBlooms dance in colorful hues, painting the day bright,   \nRains gently cleanse, as nature ignites.  \n\nChirping returns, echoes of hope in the air,   \nSpring's renewal whispers life’s promise everywhere.  \n\nAmidst vibrant shades, fields blossom and sprout,  \nNew life awakens, casting winter's doubts.  \n\nYet in the sun's glow, a shadow's gentle tease:  \nBehind spring's rebirth, lingers an autumn breeze.", type='TextMessage')], stop_reason='Maximum number of turns 3 reached.')

# %%
from autogen_agentchat.ui import Console

await Console(team.run_stream(task = 'Write a poem on the Spring Season'))
# Out:
# ---------- TextMessage (user) ----------
# Write a poem on the Spring Season
# ---------- TextMessage (plot_writer) ----------
# Blossoms arise, skies clear, earth brightens; Spring's grace renews all life.
# ---------- TextMessage (character_writer) ----------
# Rivers sing, fields awake, gentle sun bathes; Spring's warmth nurtures hearts.
# ---------- TextMessage (ending_writer) ----------
# In Spring's dance of rebirth, old dreams fade; future pathways intertwine unexpectedly.
# TaskResult(messages=[TextMessage(id='eb43e6db-de7d-4be8-8f23-d7236be2525e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 28, 37656, tzinfo=datetime.timezone.utc), content='Write a poem on the Spring Season', type='TextMessage'), TextMessage(id='7a1b196a-9212-4888-9d70-f2a725475a83', source='plot_writer', models_usage=RequestUsage(prompt_tokens=1000, completion_tokens=20), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 28, 808240, tzinfo=datetime.timezone.utc), content="Blossoms arise, skies clear, earth brightens; Spring's grace renews all life.", type='TextMessage'), TextMessage(id='bfcc2817-7628-40bb-b8a3-feef387a308d', source='character_writer', models_usage=RequestUsage(prompt_tokens=989, completion_tokens=19), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 29, 689655, tzinfo=datetime.timezone.utc), content="Rivers sing, fields awake, gentle sun bathes; Spring's warmth nurtures hearts.", type='TextMessage'), TextMessage(id='c358be46-69fe-4fba-8f41-a52a18116bcf', source='ending_writer', models_usage=RequestUsage(prompt_tokens=1032, completion_tokens=18), metadata={}, created_at=datetime.datetime(2026, 2, 28, 4, 16, 30, 572323, tzinfo=datetime.timezone.utc), content="In Spring's dance of rebirth, old dreams fade; future pathways intertwine unexpectedly.", type='TextMessage')], stop_reason='Maximum number of turns 3 reached.')
